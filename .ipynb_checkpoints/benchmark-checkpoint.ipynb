# %%
import sys
import os
from PIL import Image
import matplotlib.pyplot as plt

sys.path.append('python')

from gaussian import apply_gaussian
from sobel import apply_sobel
from median import apply_median

# Input
INPUT_PATH = 'data/epic_imagen.jpg'

# Aplica los 3 filtros
apply_gaussian(INPUT_PATH, 'data/gaussian_output.png')
apply_sobel(INPUT_PATH,    'data/sobel_output.png')
apply_median(INPUT_PATH,   'data/median_output.png')

# Visualiza
images = {
    'Original': INPUT_PATH,
    'Gaussian': 'data/gaussian_output.png',
    'Sobel':    'data/sobel_output.png',
    'Median':   'data/median_output.png',
}

fig, axes = plt.subplots(1, 4, figsize=(18, 5))

for ax, (title, path) in zip(axes, images.items()):
    img = Image.open(path)
    ax.imshow(img, cmap='gray')
    ax.set_title(title, fontsize=13)
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 16
#      13 INPUT_PATH = 'data/epic_image.jpg'
#      15 # Aplica los 3 filtros
# ---> 16 apply_gaussian(INPUT_PATH, 'data/gaussian_output.png')
#      17 apply_sobel(INPUT_PATH,    'data/sobel_output.png')
#      18 apply_median(INPUT_PATH,   'data/median_output.png')
#
# File ~/dev/UPY/7a/hpc/image-processing/python/gaussian.py:17, in apply_gaussian(image_path, output_path)
#      16 def apply_gaussian(image_path, output_path="gaussian_output.png"):
# ---> 17     img = Image.open(image_path).convert("L")  # Grayscale
#      18     pixels = img.load()
#      19     width, height = img.size
#
# File ~/dev/UPY/7a/hpc/image-processing/env/lib/python3.12/site-packages/PIL/Image.py:3512, in open(fp, mode, formats)
#    3510 if is_path(fp):
#    3511     filename = os.fspath(fp)
# -> 3512     fp = builtins.open(filename, "rb")
#    3513     exclusive_fp = True
#    3514 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/epic_image.jpg'

# %%
asda
